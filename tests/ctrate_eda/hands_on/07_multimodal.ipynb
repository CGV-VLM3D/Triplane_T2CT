# %% [markdown]
# # 07 — 질환별 소견 아틀라스 (영상 + 리포트 + 라벨)
#
# 각 질환마다 뷰어 셀이 볼륨을 엽니다. `view_volume`이 그림 아래에 짝이 되는 **소견(Findings) / 결론(Impression) + 라벨**을 자동으로 출력하므로, 영상 소견과 텍스트를 함께 볼 수 있습니다. 각 제목에 권장 윈도우가 적혀 있습니다.
#
# 단위: 영상은 reconstruction 단위, 리포트/라벨은 scan 단위.

# %%
# %matplotlib widget
import sys; sys.path.insert(0, '/workspace/tests/ctrate_eda/scripts')
from viewer import *

# %% [markdown]
# ## 정상 (기준)
# _권장 윈도우: **lung**._ 양성 라벨 없음 — 다른 질환과 비교할 기준이 되는 기본 소견.

# %%
view_volume('/workspace/tests/ctrate_eda_bundle/files/all-zero/valid_1000_a_1.nii.gz')
# tip: window 드롭다운을 'lung'으로 설정

# %% [markdown]
# ## 폐결절 (Lung nodule)
# _권장 윈도우: **lung**._ lung 윈도우에서 국소적인 둥근 연부조직 음영을 찾아보세요.

# %%
view_volume('/workspace/tests/ctrate_eda_bundle/files/lung-nodule-only/valid_1001_a_1.nii.gz')
# tip: window 드롭다운을 'lung'으로 설정

# %% [markdown]
# ## 폐 섬유화 후유증 (Pulmonary fibrotic sequela)
# _권장 윈도우: **lung**._ 말초부 망상 음영(reticulation) / 구조 왜곡(architectural distortion).

# %%
view_volume('/workspace/tests/ctrate_eda_bundle/files/diffuse-low-burden/valid_1022_a_1.nii.gz')
# tip: window 드롭다운을 'lung'으로 설정

# %% [markdown]
# ## 의료 물질 (Medical material)
# _권장 윈도우: **mediastinal**._ 밝은 금속성 물질 — mediastinal/bone 윈도우로 보세요.

# %%
view_volume('/workspace/tests/ctrate_eda_bundle/files/medical-material/valid_1288_a_1.nii.gz')
# tip: window 드롭다운을 'mediastinal'로 설정

# %% [markdown]
# ## 다발성 이상소견 (림프절/무기폐)
# _권장 윈도우: **mediastinal**._ 여러 소견이 동시에 존재 — 라벨 목록을 꼼꼼히 읽으세요.

# %%
view_volume('/workspace/tests/ctrate_eda_bundle/files/multi-abnormality/valid_1016_b_1.nii.gz')
# tip: window 드롭다운을 'mediastinal'로 설정

# %% [markdown]
# ## 심비대 + 관상동맥 석회화
# _권장 윈도우: **mediastinal**._ 확대된 심장 음영; 밝은 관상동맥 석회화.

# %%
view_volume('/workspace/tests/ctrate_eda_bundle/files/multi-abnormality/valid_1078_a_1.nii.gz')
# tip: window 드롭다운을 'mediastinal'로 설정
